# %%
import pandas as pd

# %%
read_weekdays = pd.read_excel('tables/weekdays.xlsx', header=0)

# %%
read_weekdays.head()
# Out:
#                   date weekday
# 0  2016-01-01 00:00:00  Friday
# 1  2016-01-01 00:00:00  Friday
# 2  2016-01-01 00:00:00  Friday
# 3  2016-01-01 00:00:00  Friday
# 4  2016-01-01 00:00:00  Friday

# %%
topic = pd.read_excel('tables/wikidata.xlsx', sheet_name='topics', header=0)

topic.head()
# Out:
#         date                                               page  visits  \
# 0 2016-01-01        .xxx_en.wikipedia.org_all-access_all-agents    7089
# 1 2016-01-01        .xxx_en.wikipedia.org_mobile-web_all-agents    6182
# 2 2016-01-01        1._Juli_de.wikipedia.org_desktop_all-agents      20
# 3 2016-01-01  2014_FIFA_World_Cup_en.wikipedia.org_all-acces...    5363
# 4 2016-01-01  2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...    3186
#
#                    topics
# 0                 .xxx_en
# 1                 .xxx_en
# 2              1._Juli_de
# 3  2014_FIFA_World_Cup_en
# 4  2014_FIFA_World_Cup_en

# %%
language = pd.read_excel('tables/wikidata.xlsx', sheet_name='language', header=0)

language.head()
# Out:
#         date                                               page  visits  \
# 0 2016-01-01        .xxx_en.wikipedia.org_all-access_all-agents    7089
# 1 2016-01-01        .xxx_en.wikipedia.org_mobile-web_all-agents    6182
# 2 2016-01-01        1._Juli_de.wikipedia.org_desktop_all-agents      20
# 3 2016-01-01  2014_FIFA_World_Cup_en.wikipedia.org_all-acces...    5363
# 4 2016-01-01  2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...    3186
#
#   language
# 0       en
# 1       en
# 2       de
# 3       en
# 4       en

# %%
mobile_devices = pd.read_excel('tables/wikidata.xlsx', sheet_name='mobile', header=0)

mobile_devices.head()
# Out:
#                   date                                               page  \
# 0  2016-01-01 00:00:00        .xxx_en.wikipedia.org_mobile-web_all-agents
# 1  2016-01-01 00:00:00  2014_FIFA_World_Cup_en.wikipedia.org_mobile-we...
# 2  2016-01-01 00:00:00  2015_Copa_AmÃ©rica_en.wikipedia.org_mobile-web...
# 3  2016-01-01 00:00:00  2015_in_film_en.wikipedia.org_mobile-web_all-a...
# 4  2016-01-01 00:00:00  2015å¹´å…«ä»™æ¨‚åœ’æ´¾å°ç²‰å¡µçˆ†ç‚¸äº‹æ•…_zh...
#
#    visits  device
# 0    6182  mobile
# 1    2136  mobile
# 2     580  mobile
# 3   22168  mobile
# 4     247  mobile

# %%
desktop_devices = pd.read_excel('tables/wikidata.xlsx', sheet_name='desktop', header=0)

desktop_devices.head()
# Out:
#                                                 page   visits   device
# 0        1._Juli_de.wikipedia.org_desktop_all-agents   118071  desktop
# 1  2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...  3937980  desktop
# 2  2015_Copa_AmÃ©rica_en.wikipedia.org_desktop_al...  1168851  desktop
# 3   2015_in_film_en.wikipedia.org_desktop_all-agents  6156798  desktop
# 4  2015â€“16_UEFA_Champions_League_en.wikipedia.o...  4191858  desktop

# %%
read_weekdays_d = read_weekdays['date'] = pd.to_datetime(read_weekdays['date']).dt.normalize()

read_weekdays
# Out:
#              date   weekday
# 0      2016-01-01    Friday
# 1      2016-01-01    Friday
# 2      2016-01-01    Friday
# 3      2016-01-01    Friday
# 4      2016-01-01    Friday
# ...           ...       ...
# 548908 2016-12-31  Saturday
# 548909 2016-12-31  Saturday
# 548910 2016-12-31  Saturday
# 548911 2016-12-31  Saturday
# 548912 2016-12-31  Saturday
#
# [548913 rows x 2 columns]

# %%
wikipedia_data = pd.read_excel('final_clean_data.xlsx',  header=0)

wikipedia_data.head()
# Out:
#         date                                               page  visits
# 0 2016-01-01        .xxx_en.wikipedia.org_all-access_all-agents    7089
# 1 2016-01-01        .xxx_en.wikipedia.org_mobile-web_all-agents    6182
# 2 2016-01-01        1._Juli_de.wikipedia.org_desktop_all-agents      20
# 3 2016-01-01  2014_FIFA_World_Cup_en.wikipedia.org_all-acces...    5363
# 4 2016-01-01  2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...    3186

# %%
language.drop("date", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12144/4214212543.py in <module>
# ----> 1 language.drop("date", axis=1, inplace=True)
#       2
#       3 language
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
language
# Out:
#                                                      page  visits language
# 0             .xxx_en.wikipedia.org_all-access_all-agents    7089       en
# 1             .xxx_en.wikipedia.org_mobile-web_all-agents    6182       en
# 2             1._Juli_de.wikipedia.org_desktop_all-agents      20       de
# 3       2014_FIFA_World_Cup_en.wikipedia.org_all-acces...    5363       en
# 4       2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...    3186       en
# ...                                                   ...     ...      ...
# 548908   Zac_Efron_en.wikipedia.org_all-access_all-agents   13146       en
# 548909  Zayn_Malik_en.wikipedia.org_all-access_all-agents   12597       en
# 548910     Zendaya_en.wikipedia.org_all-access_all-agents    6217       en
# 548911     Zendaya_en.wikipedia.org_mobile-web_all-agents    4650       en
# 548912  Zodiac_Killer_en.wikipedia.org_all-access_all-...    6659       en
#
# [548913 rows x 3 columns]

# %%
topic.drop("date", axis=1, inplace=True)
topic.drop("page", axis=1, inplace=True)
topic.drop("visits", axis=1, inplace=True)

topic
# Out:
#                         topics
# 0                      .xxx_en
# 1                      .xxx_en
# 2                   1._Juli_de
# 3       2014_FIFA_World_Cup_en
# 4       2014_FIFA_World_Cup_en
# ...                        ...
# 548909           Zayn_Malik_en
# 548910              Zendaya_en
# 548911              Zendaya_en
# 548912        Zodiac_Killer_en
# 548913                     NaN
#
# [548914 rows x 1 columns]

# %%
join_tables1 = pd.concat([read_weekdays, language, topic], axis = 1)

join_tables2 = join_tables1.drop(labels= 548913, axis=0)

# %%
#print(join_tables2)

join_tables2
# Out:
#              date   weekday  \
# 0      2016-01-01    Friday
# 1      2016-01-01    Friday
# 2      2016-01-01    Friday
# 3      2016-01-01    Friday
# 4      2016-01-01    Friday
# ...           ...       ...
# 548908 2016-12-31  Saturday
# 548909 2016-12-31  Saturday
# 548910 2016-12-31  Saturday
# 548911 2016-12-31  Saturday
# 548912 2016-12-31  Saturday
#
#                                                      page   visits language  \
# 0             .xxx_en.wikipedia.org_all-access_all-agents   7089.0       en
# 1             .xxx_en.wikipedia.org_mobile-web_all-agents   6182.0       en
# 2             1._Juli_de.wikipedia.org_desktop_all-agents     20.0       de
# 3       2014_FIFA_World_Cup_en.wikipedia.org_all-acces...   5363.0       en
# 4       2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...   3186.0       en
# ...                                                   ...      ...      ...
# 548908   Zac_Efron_en.wikipedia.org_all-access_all-agents  13146.0       en
# ...

# %%
final_wiki1 = join_tables2

# %%
final_wiki1.to_csv('tables/finalwiki1.csv')

# %%
merge_devices1 = pd.merge(wikipedia_data, mobile_devices, how='left', on='page').drop_duplicates()

merge_devices1
# Out:
#              date_x                                               page  \
# 0        2016-01-01        .xxx_en.wikipedia.org_all-access_all-agents
# 1        2016-01-01        .xxx_en.wikipedia.org_mobile-web_all-agents
# 2        2016-01-01        .xxx_en.wikipedia.org_mobile-web_all-agents
# 3        2016-01-01        .xxx_en.wikipedia.org_mobile-web_all-agents
# 4        2016-01-01        .xxx_en.wikipedia.org_mobile-web_all-agents
# ...             ...                                                ...
# 40091548 2016-12-31     Zendaya_en.wikipedia.org_mobile-web_all-agents
# 40091549 2016-12-31     Zendaya_en.wikipedia.org_mobile-web_all-agents
# 40091550 2016-12-31     Zendaya_en.wikipedia.org_mobile-web_all-agents
# 40091551 2016-12-31     Zendaya_en.wikipedia.org_mobile-web_all-agents
# 40091552 2016-12-31  Zodiac_Killer_en.wikipedia.org_all-access_all-...
#
#           visits_x               date_y  visits_y  device
# ...

# %%
mobile_devices
# Out:
#                        date  \
# 0       2016-01-01 00:00:00
# 1       2016-01-01 00:00:00
# 2       2016-01-01 00:00:00
# 3       2016-01-01 00:00:00
# 4       2016-01-01 00:00:00
# ...                     ...
# 108332  2016-12-31 00:00:00
# 108333  2016-12-31 00:00:00
# 108334  2016-12-31 00:00:00
# 108335  2016-12-31 00:00:00
# 108336                  NaN
#
#                                                      page      visits  device
# 0             .xxx_en.wikipedia.org_mobile-web_all-agents        6182  mobile
# 1       2014_FIFA_World_Cup_en.wikipedia.org_mobile-we...        2136  mobile
# 2       2015_Copa_AmÃ©rica_en.wikipedia.org_mobile-web...         580  mobile
# 3       2015_in_film_en.wikipedia.org_mobile-web_all-a...       22168  mobile
# 4       2015å¹´å…«ä»™æ¨‚åœ’æ´¾å°ç²‰å¡µçˆ†ç‚¸äº‹æ•…_zh...         247  mobile
# ...                                                   ...         ...     ...
# ...
