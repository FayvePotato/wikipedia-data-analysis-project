# %%
import pandas as pd

pages_dirty = pd.read_excel('wikipedia_dataset.xlsx')
pages_dirty
# Out:
#                                                    Page  2016-01-01 00:00:00  \
# 0           .xxx_en.wikipedia.org_all-access_all-agents                 7089
# 1           .xxx_en.wikipedia.org_mobile-web_all-agents                 6182
# 2           1._Juli_de.wikipedia.org_desktop_all-agents                   20
# 3     2014_FIFA_World_Cup_en.wikipedia.org_all-acces...                 5363
# 4     2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...                 3186
# ...                                                 ...                  ...
# 1495   Zac_Efron_en.wikipedia.org_all-access_all-agents                14396
# 1496  Zayn_Malik_en.wikipedia.org_all-access_all-agents                31663
# 1497     Zendaya_en.wikipedia.org_all-access_all-agents                 7091
# 1498     Zendaya_en.wikipedia.org_mobile-web_all-agents                 5221
# 1499  Zodiac_Killer_en.wikipedia.org_all-access_all-...                 4251
#
# ...

# %%
flat_pages_dirty = pd.read_excel('wikipedia_dataset_flat.xlsx')
flat_pages_dirty
# Out:
#         Unnamed: 0       date  \
# 0                0 2016-01-01
# 1                1 2016-01-01
# 2                2 2016-01-01
# 3                3 2016-01-01
# 4                4 2016-01-01
# ...            ...        ...
# 548995      548995 2016-12-31
# 548996      548996 2016-12-31
# 548997      548997 2016-12-31
# 548998      548998 2016-12-31
# 548999      548999 2016-12-31
#
#                                                      page   visits
# 0             .xxx_en.wikipedia.org_all-access_all-agents   7089.0
# 1             .xxx_en.wikipedia.org_mobile-web_all-agents   6182.0
# 2             1._Juli_de.wikipedia.org_desktop_all-agents     20.0
# 3       2014_FIFA_World_Cup_en.wikipedia.org_all-acces...   5363.0
# 4       2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...   3186.0
# ...                                                   ...      ...
# 548995   Zac_Efron_en.wikipedia.org_all-access_all-agents  13146.0
# ...

# %%
flat_pages_dirty.page.unique()
# Out:
# array(['.xxx_en.wikipedia.org_all-access_all-agents',
#        '.xxx_en.wikipedia.org_mobile-web_all-agents',
#        '1._Juli_de.wikipedia.org_desktop_all-agents', ...,
#        'Zendaya_en.wikipedia.org_all-access_all-agents',
#        'Zendaya_en.wikipedia.org_mobile-web_all-agents',
#        'Zodiac_Killer_en.wikipedia.org_all-access_all-agents'],
#       dtype=object)

# %%
flat_pages_dirty.page
# Out:
# 0               .xxx_en.wikipedia.org_all-access_all-agents
# 1               .xxx_en.wikipedia.org_mobile-web_all-agents
# 2               1._Juli_de.wikipedia.org_desktop_all-agents
# 3         2014_FIFA_World_Cup_en.wikipedia.org_all-acces...
# 4         2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...
#                                 ...
# 548995     Zac_Efron_en.wikipedia.org_all-access_all-agents
# 548996    Zayn_Malik_en.wikipedia.org_all-access_all-agents
# 548997       Zendaya_en.wikipedia.org_all-access_all-agents
# 548998       Zendaya_en.wikipedia.org_mobile-web_all-agents
# 548999    Zodiac_Killer_en.wikipedia.org_all-access_all-...
# Name: page, Length: 549000, dtype: object

# %%
sample_clean_data =flat_pages_dirty.fillna('unknown')
sample_clean_data
# Out:
#         Unnamed: 0       date  \
# 0                0 2016-01-01
# 1                1 2016-01-01
# 2                2 2016-01-01
# 3                3 2016-01-01
# 4                4 2016-01-01
# ...            ...        ...
# 548995      548995 2016-12-31
# 548996      548996 2016-12-31
# 548997      548997 2016-12-31
# 548998      548998 2016-12-31
# 548999      548999 2016-12-31
#
#                                                      page   visits
# 0             .xxx_en.wikipedia.org_all-access_all-agents   7089.0
# 1             .xxx_en.wikipedia.org_mobile-web_all-agents   6182.0
# 2             1._Juli_de.wikipedia.org_desktop_all-agents     20.0
# 3       2014_FIFA_World_Cup_en.wikipedia.org_all-acces...   5363.0
# 4       2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...   3186.0
# ...                                                   ...      ...
# 548995   Zac_Efron_en.wikipedia.org_all-access_all-agents  13146.0
# ...

# %%
print(sample_clean_data['page'].isin(['unknown']))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 548995    False
# 548996    False
# 548997    False
# 548998    False
# 548999    False
# Name: page, Length: 549000, dtype: bool

# %%
sample_clean_data.to_excel('sample_clean_data.xlsx')

# %%
print(sample_clean_data['visits'].isin(['unknown']))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 548995    False
# 548996    False
# 548997    False
# 548998    False
# 548999    False
# Name: visits, Length: 549000, dtype: bool

# %%
unknown_pages = (sample_clean_data['page'].isin(['unknown']))
unknown_visits = (sample_clean_data['visits'].isin(['unknown']))

unknown_pages.to_excel('unknown_pages.xlsx')
unknown_visits.to_excel('unknown_visits.xlsx')

# %% [markdown]
# discovered a number of missing values in the visits coloumn &
# no missing values in the pages coloumn

# %%
clean_data_v1 = flat_pages_dirty.dropna()
clean_data_v1
# Out:
#         Unnamed: 0       date  \
# 0                0 2016-01-01
# 1                1 2016-01-01
# 2                2 2016-01-01
# 3                3 2016-01-01
# 4                4 2016-01-01
# ...            ...        ...
# 548995      548995 2016-12-31
# 548996      548996 2016-12-31
# 548997      548997 2016-12-31
# 548998      548998 2016-12-31
# 548999      548999 2016-12-31
#
#                                                      page   visits
# 0             .xxx_en.wikipedia.org_all-access_all-agents   7089.0
# 1             .xxx_en.wikipedia.org_mobile-web_all-agents   6182.0
# 2             1._Juli_de.wikipedia.org_desktop_all-agents     20.0
# 3       2014_FIFA_World_Cup_en.wikipedia.org_all-acces...   5363.0
# 4       2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...   3186.0
# ...                                                   ...      ...
# 548995   Zac_Efron_en.wikipedia.org_all-access_all-agents  13146.0
# ...

# %%
clean_data_v2 = clean_data_v1.drop_duplicates()
clean_data_v2.drop(['Unnamed: 0'], axis='columns', inplace=True)

clean_data_v2
# Out:
#              date                                               page   visits
# 0      2016-01-01        .xxx_en.wikipedia.org_all-access_all-agents   7089.0
# 1      2016-01-01        .xxx_en.wikipedia.org_mobile-web_all-agents   6182.0
# 2      2016-01-01        1._Juli_de.wikipedia.org_desktop_all-agents     20.0
# 3      2016-01-01  2014_FIFA_World_Cup_en.wikipedia.org_all-acces...   5363.0
# 4      2016-01-01  2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...   3186.0
# ...           ...                                                ...      ...
# 548995 2016-12-31   Zac_Efron_en.wikipedia.org_all-access_all-agents  13146.0
# 548996 2016-12-31  Zayn_Malik_en.wikipedia.org_all-access_all-agents  12597.0
# 548997 2016-12-31     Zendaya_en.wikipedia.org_all-access_all-agents   6217.0
# 548998 2016-12-31     Zendaya_en.wikipedia.org_mobile-web_all-agents   4650.0
# 548999 2016-12-31  Zodiac_Killer_en.wikipedia.org_all-access_all-...   6659.0
#
# [548913 rows x 3 columns]

# %%
clean_data_v2.groupby('page').date.count()
# Out:
# page
# .xxx_en.wikipedia.org_all-access_all-agents                             366
# .xxx_en.wikipedia.org_mobile-web_all-agents                             366
# 1._Juli_de.wikipedia.org_desktop_all-agents                             366
# 2014_FIFA_World_Cup_en.wikipedia.org_all-access_all-agents              366
# 2014_FIFA_World_Cup_en.wikipedia.org_desktop_all-agents                 366
#                                                                        ...
# éŸ¿ã‘!_ãƒ¦ãƒ¼ãƒ•ã‚©ãƒ‹ã‚¢ãƒ _ja.wikipedia.org_desktop_all-agents       366
# éŸ¿ã‘!_ãƒ¦ãƒ¼ãƒ•ã‚©ãƒ‹ã‚¢ãƒ _ja.wikipedia.org_mobile-web_all-agents    366
# é‡‘ç”°æœ‹å­_ja.wikipedia.org_all-access_all-agents                     366
# é‡‘ç”°æœ‹å­_ja.wikipedia.org_mobile-web_all-agents                     366
# é€²æ’ƒã®å·¨äºº_ja.wikipedia.org_all-access_all-agents                  366
# Name: date, Length: 1500, dtype: int64

# %% [markdown]
# 1500 unique web pages

# %%
final_clean_data = clean_data_v2

final_clean_data
# Out:
#              date                                               page   visits
# 0      2016-01-01        .xxx_en.wikipedia.org_all-access_all-agents   7089.0
# 1      2016-01-01        .xxx_en.wikipedia.org_mobile-web_all-agents   6182.0
# 2      2016-01-01        1._Juli_de.wikipedia.org_desktop_all-agents     20.0
# 3      2016-01-01  2014_FIFA_World_Cup_en.wikipedia.org_all-acces...   5363.0
# 4      2016-01-01  2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...   3186.0
# ...           ...                                                ...      ...
# 548995 2016-12-31   Zac_Efron_en.wikipedia.org_all-access_all-agents  13146.0
# 548996 2016-12-31  Zayn_Malik_en.wikipedia.org_all-access_all-agents  12597.0
# 548997 2016-12-31     Zendaya_en.wikipedia.org_all-access_all-agents   6217.0
# 548998 2016-12-31     Zendaya_en.wikipedia.org_mobile-web_all-agents   4650.0
# 548999 2016-12-31  Zodiac_Killer_en.wikipedia.org_all-access_all-...   6659.0
#
# [548913 rows x 3 columns]

# %%
final_clean_data.to_excel('final_clean_data.xlsx')
